# %%
import pandas as pd
import datetime
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[32], line 3
#       1 import pandas as pd
#       2 import datetime
# ----> 3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
df = pd.read_csv(r"C:\Users\user\Downloads\aircrashesFullData.csv")

# %%
# !pip install pandas

# %%
df. shape
# Out:
# (5030, 12)

# %%
df.columns
# Out:
# Index(['Year', 'Quarter', 'Month', 'Day', 'Country/Region',
#        'Aircraft Manufacturer', 'Aircraft', 'Location', 'Operator',
#        'Sum of Ground', 'Sum of Fatalities (air)', 'Sum of Aboard'],
#       dtype='str')

# %%
df.head(5)
# Out:
#    Year Quarter      Month  Day Country/Region Aircraft Manufacturer  \
# 0  1908   Qtr 3  September   17       Virginia          Wright Flyer
# 1  1909   Qtr 3  September    7        France?                Wright
# 2  1912   Qtr 3       July   12            New            Dirigible?
# 3  1913   Qtr 3     August    6        British               Curtiss
# 4  1913   Qtr 3  September    9            NaN              Zeppelin
#
#                   Aircraft                                  Location  \
# 0        Wright Flyer III?                        Fort Myer Virginia
# 1        Wright ByplaneSC1                   Juvisy-sur-Orge France?
# 2               Dirigible?                         Atlantic City New
# 3        Curtiss seaplane?                          Victoria British
# 4  Zeppelin L 1 (airship)?  Over the North SeaMilitary - German Navy
#
#                            Operator  Sum of Ground  Sum of Fatalities (air)  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       Year Quarter      Month  Day Country/Region Aircraft Manufacturer  \
# 0     1908   Qtr 3  September   17       Virginia          Wright Flyer
# 1     1909   Qtr 3  September    7        France?                Wright
# 2     1912   Qtr 3       July   12            New            Dirigible?
# 3     1913   Qtr 3     August    6        British               Curtiss
# 4     1913   Qtr 3  September    9            NaN              Zeppelin
# ...    ...     ...        ...  ...            ...                   ...
# 5025  2022   Qtr 4   November    6       Tanzania                   ATR
# 5026  2022   Qtr 4   November   18           Peru                Airbus
# 5027  2022   Qtr 4   November   21       Colombia                 Piper
# 5028  2023   Qtr 1    January   15          Nepal                   ATR
# 5029  2023   Qtr 3  September   16         Brazil               Embraer
#
#                              Aircraft  \
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Year Quarter      Month  Day Country/Region Aircraft Manufacturer  \
# 0     1908   Qtr 3  September   17       Virginia          Wright Flyer
# 1     1909   Qtr 3  September    7        France?                Wright
# 2     1912   Qtr 3       July   12            New            Dirigible?
# 3     1913   Qtr 3     August    6        British               Curtiss
# 4     1913   Qtr 3  September    9            NaN              Zeppelin
# ...    ...     ...        ...  ...            ...                   ...
# 5025  2022   Qtr 4   November    6       Tanzania                   ATR
# 5026  2022   Qtr 4   November   18           Peru                Airbus
# 5027  2022   Qtr 4   November   21       Colombia                 Piper
# 5028  2023   Qtr 1    January   15          Nepal                   ATR
# 5029  2023   Qtr 3  September   16         Brazil               Embraer
#
#                              Aircraft  \
# ...

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of       Year Quarter      Month  Day Country/Region Aircraft Manufacturer  \
# 0     1908   Qtr 3  September   17       Virginia          Wright Flyer
# 1     1909   Qtr 3  September    7        France?                Wright
# 2     1912   Qtr 3       July   12            New            Dirigible?
# 3     1913   Qtr 3     August    6        British               Curtiss
# 4     1913   Qtr 3  September    9            NaN              Zeppelin
# ...    ...     ...        ...  ...            ...                   ...
# 5025  2022   Qtr 4   November    6       Tanzania                   ATR
# 5026  2022   Qtr 4   November   18           Peru                Airbus
# 5027  2022   Qtr 4   November   21       Colombia                 Piper
# 5028  2023   Qtr 1    January   15          Nepal                   ATR
# 5029  2023   Qtr 3  September   16         Brazil               Embraer
#
#                              Aircraft  \
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5025    False
# 5026    False
# 5027    False
# 5028    False
# 5029    False
# Length: 5030, dtype: bool

# %%
df.dtypes
# Out:
# Year                       int64
# Quarter                      str
# Month                        str
# Day                        int64
# Country/Region               str
# Aircraft Manufacturer        str
# Aircraft                     str
# Location                     str
# Operator                     str
# Sum of Ground              int64
# Sum of Fatalities (air)    int64
# Sum of Aboard              int64
# dtype: object

# %%
df['date'] = pd.to_datetime(
df['Year'] . astype(str) + ' ' +
df['Month'] + ' '+
df['Day']. astype(str)
)

# %%
df = df.dropna(subset=['date', 'Location'])
df['Sum of Fatalities (air)'] = df['Sum of Fatalities (air)'].fillna(0)
df = df.drop_duplicates()

# %%
## 1- air crashes changes over time
